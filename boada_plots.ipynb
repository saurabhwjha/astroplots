# %%
import matplotlib.pyplot as plt
from astropy.table import Table
# %matplotlib notebook

# %%
filters = [i for i in 'ugrizJHK']

# %%
filters
# Out:
# ['u', 'g', 'r', 'i', 'z', 'J', 'H', 'K']

# %%
for filt in filters:
    f = Table.read(f'./boada_plot_data/{filt}.res', format='ascii')
    plt.plot(f['col1'], f['col2'])
    
plt.xlabel('$\lambda$')
plt.ylabel('Transmission')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Transmission')
